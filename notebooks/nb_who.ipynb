# %%
import os
import pandas as pd

root_dir = os.getcwd()
csv_file_path = root_dir + os.sep + 'data/who/WHO.csv'
data = pd.read_csv(csv_file_path, index_col=0, parse_dates=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 146940 entries, 2020-01-03 to 2021-09-13
# Data columns (total 7 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Country_code       146320 non-null  object
#  1   Country            146940 non-null  object
#  2   WHO_region         146940 non-null  object
#  3   New_cases          146940 non-null  int64
#  4   Cumulative_cases   146940 non-null  int64
#  5   New_deaths         146940 non-null  int64
#  6   Cumulative_deaths  146940 non-null  int64
# dtypes: int64(4), object(3)
# memory usage: 9.0+ MB

# %%
list(data.keys())
# Out:
# ['Country_code',
#  'Country',
#  'WHO_region',
#  'New_cases',
#  'Cumulative_cases',
#  'New_deaths',
#  'Cumulative_deaths']

# %%
data.value_counts()
# Out:
# Country_code  Country                           WHO_region  New_cases  Cumulative_cases  New_deaths  Cumulative_deaths
# TO            Tonga                             WPRO        0          0                 0           0                    620
# TV            Tuvalu                            WPRO        0          0                 0           0                    620
# TM            Turkmenistan                      EURO        0          0                 0           0                    620
# AS            American Samoa                    WPRO        0          0                 0           0                    620
# FM            Micronesia (Federated States of)  WPRO        0          0                 0           0                    620
#                                                                                                                          ...
# GM            Gambia                            AFRO        0          4469              0           138                    1
#                                                                        4414              0           138                    1
#                                                                        4237              0           134                    1
#                                                                        4139              0           131                    1
# ZW            Zimbabwe                          AFRO        4213       60227             34          1973                   1
# Length: 99077, dtype: int64

# %%
data.head()
# Out:
#               Country_code      Country WHO_region  New_cases  \
# Date_reported
# 2020-01-03              AF  Afghanistan       EMRO          0
# 2020-01-04              AF  Afghanistan       EMRO          0
# 2020-01-05              AF  Afghanistan       EMRO          0
# 2020-01-06              AF  Afghanistan       EMRO          0
# 2020-01-07              AF  Afghanistan       EMRO          0
#
#                Cumulative_cases  New_deaths  Cumulative_deaths
# Date_reported
# 2020-01-03                    0           0                  0
# 2020-01-04                    0           0                  0
# 2020-01-05                    0           0                  0
# 2020-01-06                    0           0                  0
# 2020-01-07                    0           0                  0

# %%
data.tail()
# Out:
#               Country_code   Country WHO_region  New_cases  Cumulative_cases  \
# Date_reported
# 2021-09-09              ZW  Zimbabwe       AFRO        260            125931
# 2021-09-10              ZW  Zimbabwe       AFRO        125            126056
# 2021-09-11              ZW  Zimbabwe       AFRO        107            126163
# 2021-09-12              ZW  Zimbabwe       AFRO         57            126220
# 2021-09-13              ZW  Zimbabwe       AFRO         49            126269
#
#                New_deaths  Cumulative_deaths
# Date_reported
# 2021-09-09             24               4517
# 2021-09-10              4               4521
# 2021-09-11             11               4532
# 2021-09-12              4               4536
# 2021-09-13              2               4538

# %%
data
# Out:
#               Country_code      Country WHO_region  New_cases  \
# Date_reported
# 2020-01-03              AF  Afghanistan       EMRO          0
# 2020-01-04              AF  Afghanistan       EMRO          0
# 2020-01-05              AF  Afghanistan       EMRO          0
# 2020-01-06              AF  Afghanistan       EMRO          0
# 2020-01-07              AF  Afghanistan       EMRO          0
# ...                    ...          ...        ...        ...
# 2021-09-09              ZW     Zimbabwe       AFRO        260
# 2021-09-10              ZW     Zimbabwe       AFRO        125
# 2021-09-11              ZW     Zimbabwe       AFRO        107
# 2021-09-12              ZW     Zimbabwe       AFRO         57
# 2021-09-13              ZW     Zimbabwe       AFRO         49
#
#                Cumulative_cases  New_deaths  Cumulative_deaths
# Date_reported
# 2020-01-03                    0           0                  0
# 2020-01-04                    0           0                  0
# 2020-01-05                    0           0                  0
# 2020-01-06                    0           0                  0
# 2020-01-07                    0           0                  0
# ...                         ...         ...                ...
# 2021-09-09               125931          24               4517
# 2021-09-10               126056           4               4521
# 2021-09-11               126163          11               4532
# 2021-09-12               126220           4               4536
# 2021-09-13               126269           2               4538
#
# [146940 rows x 7 columns]

# %%
data.plot()
# Out:
# <AxesSubplot:xlabel='Date_reported'>

# %%
data["New_cases"].plot()
# Out:
# <AxesSubplot:xlabel='Date_reported'>

# %%
data["New_deaths"].plot()
# Out:
# <AxesSubplot:xlabel='Date_reported'>

# %%
data["Cumulative_cases"].plot()
# Out:
# <AxesSubplot:xlabel='Date_reported'>

# %%
data["Cumulative_deaths"].plot()
# Out:
# <AxesSubplot:xlabel='Date_reported'>
