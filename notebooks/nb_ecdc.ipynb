# %%
import os
import pandas as pd

root_dir = os.getcwd()
csv_file_path = root_dir + os.sep + 'data/ecdc/ECDC.csv'
data = pd.read_csv(csv_file_path, index_col=0, parse_dates=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 61900 entries, 2020-12-14 to 2020-03-21
# Data columns (total 11 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   day                                                         61900 non-null  int64
#  1   month                                                       61900 non-null  int64
#  2   year                                                        61900 non-null  int64
#  3   cases                                                       61900 non-null  int64
#  4   deaths                                                      61900 non-null  int64
#  5   countriesAndTerritories                                     61900 non-null  object
#  6   geoId                                                       61625 non-null  object
# ...

# %%
list(data.keys())
# Out:
# ['day',
#  'month',
#  'year',
#  'cases',
#  'deaths',
#  'countriesAndTerritories',
#  'geoId',
#  'countryterritoryCode',
#  'popData2019',
#  'continentExp',
#  'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000']

# %%
data.value_counts()
# Out:
# day  month  year  cases   deaths  countriesAndTerritories   geoId  countryterritoryCode  popData2019   continentExp  Cumulative_number_for_14_days_of_COVID-19_cases_per_100000
# 1    2      2020  0       0       Afghanistan               AF     AFG                   3.804176e+07  Asia          0.000000                                                      1
# 21   4      2020  367     15      Japan                     JP     JPN                   1.268603e+08  Asia          5.684994                                                      1
#                   419     6       Chile                     CL     CHL                   1.895204e+07  America       30.033714                                                     1
#                   457     4       Belarus                   BY     BLR                   9.452409e+06  Europe        58.863301                                                     1
# ...

# %%
data.head()
# Out:
#             day  month  year  cases  deaths countriesAndTerritories geoId  \
# dateRep
# 2020-12-14   14     12  2020    746       6             Afghanistan    AF
# 2020-12-13   13     12  2020    298       9             Afghanistan    AF
# 2020-12-12   12     12  2020    113      11             Afghanistan    AF
# 2020-11-12   11     12  2020     63      10             Afghanistan    AF
# 2020-10-12   10     12  2020    202      16             Afghanistan    AF
#
#            countryterritoryCode  popData2019 continentExp  \
# dateRep
# 2020-12-14                  AFG   38041757.0         Asia
# 2020-12-13                  AFG   38041757.0         Asia
# 2020-12-12                  AFG   38041757.0         Asia
# 2020-11-12                  AFG   38041757.0         Asia
# 2020-10-12                  AFG   38041757.0         Asia
#
#             Cumulative_number_for_14_days_of_COVID-19_cases_per_100000
# dateRep
# 2020-12-14                                           9.013779
# ...

# %%
data.tail()
# Out:
#             day  month  year  cases  deaths countriesAndTerritories geoId  \
# dateRep
# 2020-03-25   25      3  2020      0       0                Zimbabwe    ZW
# 2020-03-24   24      3  2020      0       1                Zimbabwe    ZW
# 2020-03-23   23      3  2020      0       0                Zimbabwe    ZW
# 2020-03-22   22      3  2020      1       0                Zimbabwe    ZW
# 2020-03-21   21      3  2020      1       0                Zimbabwe    ZW
#
#            countryterritoryCode  popData2019 continentExp  \
# dateRep
# 2020-03-25                  ZWE   14645473.0       Africa
# 2020-03-24                  ZWE   14645473.0       Africa
# 2020-03-23                  ZWE   14645473.0       Africa
# 2020-03-22                  ZWE   14645473.0       Africa
# 2020-03-21                  ZWE   14645473.0       Africa
#
#             Cumulative_number_for_14_days_of_COVID-19_cases_per_100000
# dateRep
# 2020-03-25                                                NaN
# ...

# %%
data.plot()
# Out:
# <AxesSubplot:xlabel='dateRep'>

# %%
data["cases"].plot()
# Out:
# <AxesSubplot:xlabel='dateRep'>

# %%
data["deaths"].plot()
# Out:
# <AxesSubplot:xlabel='dateRep'>
