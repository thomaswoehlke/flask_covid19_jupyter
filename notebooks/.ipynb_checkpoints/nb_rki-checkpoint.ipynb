# %%
import os
import pandas as pd

root_dir = os.getcwd()
csv_file_path = root_dir + os.sep + 'data/rki/RKI.csv'
data = pd.read_csv(csv_file_path, index_col=8, parse_dates=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2320712 entries, 2020-09-30 to 2021-09-08
# Data columns (total 17 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   FID                   int64
#  1   IdBundesland          int64
#  2   Bundesland            object
#  3   Landkreis             object
#  4   Altersgruppe          object
#  5   Geschlecht            object
#  6   AnzahlFall            int64
#  7   AnzahlTodesfall       int64
#  8   IdLandkreis           int64
#  9   Datenstand            object
#  10  NeuerFall             int64
#  11  NeuerTodesfall        int64
#  12  Refdatum              object
#  13  NeuGenesen            int64
#  14  AnzahlGenesen         int64
#  15  IstErkrankungsbeginn  int64
#  16  Altersgruppe2         object
# dtypes: int64(10), object(7)
# memory usage: 318.7+ MB

# %%
list(data.keys())
# Out:
# ['FID',
#  'IdBundesland',
#  'Bundesland',
#  'Landkreis',
#  'Altersgruppe',
#  'Geschlecht',
#  'AnzahlFall',
#  'AnzahlTodesfall',
#  'IdLandkreis',
#  'Datenstand',
#  'NeuerFall',
#  'NeuerTodesfall',
#  'Refdatum',
#  'NeuGenesen',
#  'AnzahlGenesen',
#  'IstErkrankungsbeginn',
#  'Altersgruppe2']

# %%
data.value_counts()
# Out:
# FID      IdBundesland  Bundesland          Landkreis             Altersgruppe  Geschlecht  AnzahlFall  AnzahlTodesfall  IdLandkreis  Datenstand             NeuerFall  NeuerTodesfall  Refdatum             NeuGenesen  AnzahlGenesen  IstErkrankungsbeginn  Altersgruppe2
# 1        1             Schleswig-Holstein  SK Flensburg          A00-A04       M           1           0                1001         14.09.2021, 00:00 Uhr  0          -9              2020/09/30 00:00:00   0          1              0                     Nicht übermittelt    1
# 1547145  9             Bayern              LK Passau             A35-A59       W           2           0                9275         14.09.2021, 00:00 Uhr  0          -9              2021/02/02 00:00:00   0          2              1                     Nicht übermittelt    1
# ...

# %%
data.head()
# Out:
#             FID  IdBundesland          Bundesland     Landkreis Altersgruppe  \
# Meldedatum
# 2020-09-30    1             1  Schleswig-Holstein  SK Flensburg      A00-A04
# 2020-10-29    2             1  Schleswig-Holstein  SK Flensburg      A00-A04
# 2020-11-03    3             1  Schleswig-Holstein  SK Flensburg      A00-A04
# 2020-11-20    4             1  Schleswig-Holstein  SK Flensburg      A00-A04
# 2020-11-23    5             1  Schleswig-Holstein  SK Flensburg      A00-A04
#
#            Geschlecht  AnzahlFall  AnzahlTodesfall  IdLandkreis  \
# Meldedatum
# 2020-09-30          M           1                0         1001
# 2020-10-29          M           1                0         1001
# 2020-11-03          M           1                0         1001
# 2020-11-20          M           1                0         1001
# 2020-11-23          M           1                0         1001
#
#                        Datenstand  NeuerFall  NeuerTodesfall  \
# Meldedatum
# ...

# %%
data.tail()
# Out:
#                 FID  IdBundesland Bundesland            Landkreis  \
# Meldedatum
# 2021-08-02  2320708            16  Thüringen  LK Altenburger Land
# 2021-08-07  2320709            16  Thüringen  LK Altenburger Land
# 2021-08-24  2320710            16  Thüringen  LK Altenburger Land
# 2021-08-26  2320711            16  Thüringen  LK Altenburger Land
# 2021-09-08  2320712            16  Thüringen  LK Altenburger Land
#
#            Altersgruppe Geschlecht  AnzahlFall  AnzahlTodesfall  IdLandkreis  \
# Meldedatum
# 2021-08-02         A80+          W           2                0        16077
# 2021-08-07         A80+          W           1                0        16077
# 2021-08-24         A80+          W           1                0        16077
# 2021-08-26         A80+          W           1                0        16077
# 2021-09-08         A80+          W           1                0        16077
#
#                        Datenstand  NeuerFall  NeuerTodesfall  \
# Meldedatum
# ...

# %%
data
# Out:
#                 FID  IdBundesland          Bundesland            Landkreis  \
# Meldedatum
# 2020-09-30        1             1  Schleswig-Holstein         SK Flensburg
# 2020-10-29        2             1  Schleswig-Holstein         SK Flensburg
# 2020-11-03        3             1  Schleswig-Holstein         SK Flensburg
# 2020-11-20        4             1  Schleswig-Holstein         SK Flensburg
# 2020-11-23        5             1  Schleswig-Holstein         SK Flensburg
# ...             ...           ...                 ...                  ...
# 2021-08-02  2320708            16           Thüringen  LK Altenburger Land
# 2021-08-07  2320709            16           Thüringen  LK Altenburger Land
# 2021-08-24  2320710            16           Thüringen  LK Altenburger Land
# 2021-08-26  2320711            16           Thüringen  LK Altenburger Land
# 2021-09-08  2320712            16           Thüringen  LK Altenburger Land
#
# ...

# %%
data.plot()
# Out:
# <AxesSubplot:xlabel='Meldedatum'>
