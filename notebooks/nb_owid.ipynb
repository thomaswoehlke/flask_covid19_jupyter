# %%
import os
import pandas as pd

root_dir = os.getcwd()
csv_file_path = root_dir + os.sep + 'data/owid/OWID.csv'
data = pd.read_csv(csv_file_path, index_col=3, parse_dates=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 116102 entries, 2020-02-24 to 2021-09-11
# Data columns (total 61 columns):
#  #   Column                                 Non-Null Count   Dtype
# ---  ------                                 --------------   -----
#  0   iso_code                               116102 non-null  object
#  1   continent                              110785 non-null  object
#  2   location                               116102 non-null  object
#  3   total_cases                            110469 non-null  float64
#  4   new_cases                              110466 non-null  float64
#  5   new_cases_smoothed                     109451 non-null  float64
#  6   total_deaths                           99837 non-null   float64
#  7   new_deaths                             99992 non-null   float64
#  8   new_deaths_smoothed                    109451 non-null  float64
#  9   total_cases_per_million                109886 non-null  float64
#  10  new_cases_per_million                  109883 non-null  float64
#  11  new_cases_smoothed_per_million         108873 non-null  float64
#  12  total_deaths_per_million               99267 non-null   float64
#  13  new_deaths_per_million                 99422 non-null   float64
#  14  new_deaths_smoothed_per_million        108873 non-null  float64
#  15  reproduction_rate                      93324 non-null   float64
#  16  icu_patients                           12620 non-null   float64
#  17  icu_patients_per_million               12620 non-null   float64
#  18  hosp_patients                          15086 non-null   float64
#  19  hosp_patients_per_million              15086 non-null   float64
#  20  weekly_icu_admissions                  1142 non-null    float64
#  21  weekly_icu_admissions_per_million      1142 non-null    float64
#  22  weekly_hosp_admissions                 2026 non-null    float64
#  23  weekly_hosp_admissions_per_million     2026 non-null    float64
#  24  new_tests                              50043 non-null   float64
#  25  total_tests                            49806 non-null   float64
#  26  total_tests_per_thousand               49806 non-null   float64
#  27  new_tests_per_thousand                 50043 non-null   float64
#  28  new_tests_smoothed                     59038 non-null   float64
#  29  new_tests_smoothed_per_thousand        59038 non-null   float64
#  30  positive_rate                          55804 non-null   float64
#  31  tests_per_case                         55186 non-null   float64
#  32  tests_units                            60899 non-null   object
#  33  total_vaccinations                     25015 non-null   float64
#  34  people_vaccinated                      23973 non-null   float64
#  35  people_fully_vaccinated                21017 non-null   float64
#  36  total_boosters                         1721 non-null    float64
#  37  new_vaccinations                       20707 non-null   float64
#  38  new_vaccinations_smoothed              44617 non-null   float64
#  39  total_vaccinations_per_hundred         25015 non-null   float64
#  40  people_vaccinated_per_hundred          23973 non-null   float64
#  41  people_fully_vaccinated_per_hundred    21017 non-null   float64
#  42  total_boosters_per_hundred             1721 non-null    float64
#  43  new_vaccinations_smoothed_per_million  44617 non-null   float64
#  44  stringency_index                       95552 non-null   float64
#  45  population                             115305 non-null  float64
#  46  population_density                     107369 non-null  float64
#  47  median_age                             102683 non-null  float64
#  48  aged_65_older                          101539 non-null  float64
#  49  aged_70_older                          102119 non-null  float64
#  50  gdp_per_capita                         103246 non-null  float64
#  51  extreme_poverty                        69370 non-null   float64
#  52  cardiovasc_death_rate                  102992 non-null  float64
#  53  diabetes_prevalence                    106075 non-null  float64
#  54  female_smokers                         80435 non-null   float64
#  55  male_smokers                           79265 non-null   float64
#  56  handwashing_facilities                 51736 non-null   float64
#  57  hospital_beds_per_thousand             93668 non-null   float64
#  58  life_expectancy                        110132 non-null  float64
#  59  human_development_index                103083 non-null  float64
#  60  excess_mortality                       4003 non-null    float64
# dtypes: float64(57), object(4)
# memory usage: 54.9+ MB

# %%
list(data.keys())
# Out:
# ['iso_code',
#  'continent',
#  'location',
#  'total_cases',
#  'new_cases',
#  'new_cases_smoothed',
#  'total_deaths',
#  'new_deaths',
#  'new_deaths_smoothed',
#  'total_cases_per_million',
#  'new_cases_per_million',
#  'new_cases_smoothed_per_million',
#  'total_deaths_per_million',
#  'new_deaths_per_million',
#  'new_deaths_smoothed_per_million',
#  'reproduction_rate',
#  'icu_patients',
#  'icu_patients_per_million',
#  'hosp_patients',
#  'hosp_patients_per_million',
#  'weekly_icu_admissions',
#  'weekly_icu_admissions_per_million',
#  'weekly_hosp_admissions',
#  'weekly_hosp_admissions_per_million',
#  'new_tests',
#  'total_tests',
#  'total_tests_per_thousand',
#  'new_tests_per_thousand',
#  'new_tests_smoothed',
#  'new_tests_smoothed_per_thousand',
#  'positive_rate',
#  'tests_per_case',
#  'tests_units',
#  'total_vaccinations',
#  'people_vaccinated',
#  'people_fully_vaccinated',
#  'total_boosters',
#  'new_vaccinations',
#  'new_vaccinations_smoothed',
#  'total_vaccinations_per_hundred',
#  'people_vaccinated_per_hundred',
#  'people_fully_vaccinated_per_hundred',
#  'total_boosters_per_hundred',
#  'new_vaccinations_smoothed_per_million',
#  'stringency_index',
#  'population',
#  'population_density',
#  'median_age',
#  'aged_65_older',
#  'aged_70_older',
#  'gdp_per_capita',
#  'extreme_poverty',
#  'cardiovasc_death_rate',
#  'diabetes_prevalence',
#  'female_smokers',
#  'male_smokers',
#  'handwashing_facilities',
#  'hospital_beds_per_thousand',
#  'life_expectancy',
#  'human_development_index',
#  'excess_mortality']

# %%
data.value_counts()
# Out:
# Series([], dtype: int64)

# %%
data.head()
# Out:
#            iso_code continent     location  total_cases  new_cases  \
# date
# 2020-02-24      AFG      Asia  Afghanistan          1.0        1.0
# 2020-02-25      AFG      Asia  Afghanistan          1.0        0.0
# 2020-02-26      AFG      Asia  Afghanistan          1.0        0.0
# 2020-02-27      AFG      Asia  Afghanistan          1.0        0.0
# 2020-02-28      AFG      Asia  Afghanistan          1.0        0.0
#
#             new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# date
# 2020-02-24                 NaN           NaN         NaN                  NaN
# 2020-02-25                 NaN           NaN         NaN                  NaN
# 2020-02-26                 NaN           NaN         NaN                  NaN
# 2020-02-27                 NaN           NaN         NaN                  NaN
# 2020-02-28                 NaN           NaN         NaN                  NaN
#
#             total_cases_per_million  ...  extreme_poverty  \
# date                                 ...
# 2020-02-24                    0.025  ...              NaN
# 2020-02-25                    0.025  ...              NaN
# 2020-02-26                    0.025  ...              NaN
# 2020-02-27                    0.025  ...              NaN
# 2020-02-28                    0.025  ...              NaN
#
#             cardiovasc_death_rate  diabetes_prevalence  female_smokers  \
# date
# 2020-02-24                597.029                 9.59             NaN
# 2020-02-25                597.029                 9.59             NaN
# 2020-02-26                597.029                 9.59             NaN
# 2020-02-27                597.029                 9.59             NaN
# 2020-02-28                597.029                 9.59             NaN
#
#             male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# date
# 2020-02-24           NaN                  37.746                         0.5
# 2020-02-25           NaN                  37.746                         0.5
# 2020-02-26           NaN                  37.746                         0.5
# 2020-02-27           NaN                  37.746                         0.5
# 2020-02-28           NaN                  37.746                         0.5
#
#             life_expectancy  human_development_index  excess_mortality
# date
# 2020-02-24            64.83                    0.511               NaN
# 2020-02-25            64.83                    0.511               NaN
# 2020-02-26            64.83                    0.511               NaN
# 2020-02-27            64.83                    0.511               NaN
# 2020-02-28            64.83                    0.511               NaN
#
# [5 rows x 61 columns]

# %%
data.tail()
# Out:
#            iso_code continent  location  total_cases  new_cases  \
# date
# 2021-09-07      ZWE    Africa  Zimbabwe     125796.0      125.0
# 2021-09-08      ZWE    Africa  Zimbabwe     125931.0      135.0
# 2021-09-09      ZWE    Africa  Zimbabwe     126056.0      125.0
# 2021-09-10      ZWE    Africa  Zimbabwe     126163.0      107.0
# 2021-09-11      ZWE    Africa  Zimbabwe     126220.0       57.0
#
#             new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# date
# 2021-09-07             146.143        4503.0        10.0               12.000
# 2021-09-08             138.714        4517.0        14.0               11.286
# 2021-09-09             134.000        4521.0         4.0               10.286
# 2021-09-10             118.857        4532.0        11.0               10.714
# 2021-09-11             113.571        4536.0         4.0               10.000
#
#             total_cases_per_million  ...  extreme_poverty  \
# date                                 ...
# 2021-09-07                 8335.183  ...             21.4
# 2021-09-08                 8344.128  ...             21.4
# 2021-09-09                 8352.410  ...             21.4
# 2021-09-10                 8359.500  ...             21.4
# 2021-09-11                 8363.277  ...             21.4
#
#             cardiovasc_death_rate  diabetes_prevalence  female_smokers  \
# date
# 2021-09-07                307.846                 1.82             1.6
# 2021-09-08                307.846                 1.82             1.6
# 2021-09-09                307.846                 1.82             1.6
# 2021-09-10                307.846                 1.82             1.6
# 2021-09-11                307.846                 1.82             1.6
#
#             male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# date
# 2021-09-07          30.7                  36.791                         1.7
# 2021-09-08          30.7                  36.791                         1.7
# 2021-09-09          30.7                  36.791                         1.7
# 2021-09-10          30.7                  36.791                         1.7
# 2021-09-11          30.7                  36.791                         1.7
#
#             life_expectancy  human_development_index  excess_mortality
# date
# 2021-09-07            61.49                    0.571               NaN
# 2021-09-08            61.49                    0.571               NaN
# 2021-09-09            61.49                    0.571               NaN
# 2021-09-10            61.49                    0.571               NaN
# 2021-09-11            61.49                    0.571               NaN
#
# [5 rows x 61 columns]

# %%
data
# Out:
#            iso_code continent     location  total_cases  new_cases  \
# date
# 2020-02-24      AFG      Asia  Afghanistan          1.0        1.0
# 2020-02-25      AFG      Asia  Afghanistan          1.0        0.0
# 2020-02-26      AFG      Asia  Afghanistan          1.0        0.0
# 2020-02-27      AFG      Asia  Afghanistan          1.0        0.0
# 2020-02-28      AFG      Asia  Afghanistan          1.0        0.0
# ...             ...       ...          ...          ...        ...
# 2021-09-07      ZWE    Africa     Zimbabwe     125796.0      125.0
# 2021-09-08      ZWE    Africa     Zimbabwe     125931.0      135.0
# 2021-09-09      ZWE    Africa     Zimbabwe     126056.0      125.0
# 2021-09-10      ZWE    Africa     Zimbabwe     126163.0      107.0
# 2021-09-11      ZWE    Africa     Zimbabwe     126220.0       57.0
#
#             new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# date
# 2020-02-24                 NaN           NaN         NaN                  NaN
# 2020-02-25                 NaN           NaN         NaN                  NaN
# 2020-02-26                 NaN           NaN         NaN                  NaN
# 2020-02-27                 NaN           NaN         NaN                  NaN
# 2020-02-28                 NaN           NaN         NaN                  NaN
# ...                        ...           ...         ...                  ...
# 2021-09-07             146.143        4503.0        10.0               12.000
# 2021-09-08             138.714        4517.0        14.0               11.286
# 2021-09-09             134.000        4521.0         4.0               10.286
# 2021-09-10             118.857        4532.0        11.0               10.714
# 2021-09-11             113.571        4536.0         4.0               10.000
#
#             total_cases_per_million  ...  extreme_poverty  \
# date                                 ...
# 2020-02-24                    0.025  ...              NaN
# 2020-02-25                    0.025  ...              NaN
# 2020-02-26                    0.025  ...              NaN
# 2020-02-27                    0.025  ...              NaN
# 2020-02-28                    0.025  ...              NaN
# ...                             ...  ...              ...
# 2021-09-07                 8335.183  ...             21.4
# 2021-09-08                 8344.128  ...             21.4
# 2021-09-09                 8352.410  ...             21.4
# 2021-09-10                 8359.500  ...             21.4
# 2021-09-11                 8363.277  ...             21.4
#
#             cardiovasc_death_rate  diabetes_prevalence  female_smokers  \
# date
# 2020-02-24                597.029                 9.59             NaN
# 2020-02-25                597.029                 9.59             NaN
# 2020-02-26                597.029                 9.59             NaN
# 2020-02-27                597.029                 9.59             NaN
# 2020-02-28                597.029                 9.59             NaN
# ...                           ...                  ...             ...
# 2021-09-07                307.846                 1.82             1.6
# 2021-09-08                307.846                 1.82             1.6
# 2021-09-09                307.846                 1.82             1.6
# 2021-09-10                307.846                 1.82             1.6
# 2021-09-11                307.846                 1.82             1.6
#
#             male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# date
# 2020-02-24           NaN                  37.746                         0.5
# 2020-02-25           NaN                  37.746                         0.5
# 2020-02-26           NaN                  37.746                         0.5
# 2020-02-27           NaN                  37.746                         0.5
# 2020-02-28           NaN                  37.746                         0.5
# ...                  ...                     ...                         ...
# 2021-09-07          30.7                  36.791                         1.7
# 2021-09-08          30.7                  36.791                         1.7
# 2021-09-09          30.7                  36.791                         1.7
# 2021-09-10          30.7                  36.791                         1.7
# 2021-09-11          30.7                  36.791                         1.7
#
#             life_expectancy  human_development_index  excess_mortality
# date
# 2020-02-24            64.83                    0.511               NaN
# 2020-02-25            64.83                    0.511               NaN
# 2020-02-26            64.83                    0.511               NaN
# 2020-02-27            64.83                    0.511               NaN
# 2020-02-28            64.83                    0.511               NaN
# ...                     ...                      ...               ...
# 2021-09-07            61.49                    0.571               NaN
# 2021-09-08            61.49                    0.571               NaN
# 2021-09-09            61.49                    0.571               NaN
# 2021-09-10            61.49                    0.571               NaN
# 2021-09-11            61.49                    0.571               NaN
#
# [116102 rows x 61 columns]

# %%
data.plot()
# Out:
# <AxesSubplot:xlabel='date'>
